# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('users/praneetpannu/downloads/population.csv')

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
df.shape
# Out:
# (266, 67)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
print(df['Country Name'].unique())
print("\nTotal no of unique countries:",df['Country Name'].nunique())
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
print(df['Country Code'].unique())
print("\nTotal no of unique country code:",df['Country Code'].nunique())
# Out:
# ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'INX' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN'
#  'KAZ' 'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR'
#  'LBY' 'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU'
#  'LUX' 'LVA' 'MAC' 'MAF' 'MAR' 'MCO' 'MDA' 'MDG' 'MDV' 'MEA' 'MEX' 'MHL'
# ...

# %%
# Display the number of countries for each 'Indicator Name'
indicator_counts = df.groupby('Indicator Name')['Country Name'].nunique()
print(indicator_counts)
# Out:
# Indicator Name
# Population, total    266
# Name: Country Name, dtype: int64

# %%
# Display the number of countries for each 'Indicator Code'
indicator_code_counts = df.groupby('Indicator Code')['Country Name'].nunique()
print(indicator_code_counts)
# Out:
# Indicator Code
# SP.POP.TOTL    266
# Name: Country Name, dtype: int64

# %%
# Drop 'Indicator Name' and 'Indicator Code' columns as they are unnecessary for analysis
df_cleaned = df.drop(['Indicator Name', 'Indicator Code'], axis=1)
df_cleaned.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968  ...         2013         2014         2015         2016  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# Extraction of top-10 countries with respect to total population
top_10_countries = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=False).head(10)
print(top_10_countries)
# Out:
#                    Country Name          2022
# 259                       World  7.950947e+09
# 103            IDA & IBRD total  6.754030e+09
# 140         Low & middle income  6.678280e+09
# 156               Middle income  5.974552e+09
# 102                   IBRD only  4.913887e+09
# 62   Early-demographic dividend  3.447399e+09
# 139         Lower middle income  3.190184e+09
# 249         Upper middle income  2.784368e+09
# 63          East Asia & Pacific  2.375162e+09
# 142   Late-demographic dividend  2.325543e+09

# %%
# Top ten countries of total population in year 2022 and 2016
plt.figure(figsize=(12, 6))
plt.bar(top_10_2022['Country Name'], top_10_2022['2022'], width=0.4, label='2022', align='center')
plt.bar(top_10_2016['Country Name'], top_10_2016['2016'], width=0.4, label='2016', align='edge')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Population')
plt.title('Top 10 Countries by Total Population in 2016 and 2022')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Top ten countries of total population in year 2010 and 2001
top_10_2010 = df_cleaned[['Country Name', '2010']].sort_values(by='2010', ascending=False).head(10)
top_10_2001 = df_cleaned[['Country Name', '2001']].sort_values(by='2001', ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_2010['Country Name'], top_10_2010['2010'], width=0.4, label='2010', align='center')
plt.bar(top_10_2001['Country Name'], top_10_2001['2001'], width=0.4, label='2001', align='edge')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Population')
plt.title('Top 10 Countries by Total Population in 2001 and 2010')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extraction of bottom-10 countries with respect to total population
bottom_10_countries = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=True).head(10)
print(bottom_10_countries)
# Out:
#                  Country Name     2022
# 245                    Tuvalu  11312.0
# 179                     Nauru  12668.0
# 188                     Palau  18055.0
# 255    British Virgin Islands  31305.0
# 147  St. Martin (French part)  31791.0
# 84                  Gibraltar  32649.0
# 212                San Marino  33660.0
# 149                    Monaco  36469.0
# 137             Liechtenstein  39327.0
# 155          Marshall Islands  41569.0

# %%
# Bottom ten countries of total population in year 2022 and 2016
bottom_10_2016 = df_cleaned[df_cleaned['Country Name'].isin(bottom_10_countries['Country Name'])][['Country Name', '2016']]

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_countries['Country Name'], bottom_10_countries['2022'], width=0.4, label='2022', align='center')
plt.bar(bottom_10_2016['Country Name'], bottom_10_2016['2016'], width=0.4, label='2016', align='edge')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Population')
plt.title('Bottom 10 Countries by Total Population in 2016 and 2022')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Bottom ten countries of total population in year 2010 and 2001
bottom_10_2010 = df_cleaned[df_cleaned['Country Name'].isin(bottom_10_countries['Country Name'])][['Country Name', '2010']]
bottom_10_2001 = df_cleaned[df_cleaned['Country Name'].isin(bottom_10_countries['Country Name'])][['Country Name', '2001']]

plt.figure(figsize=(12, 6))
plt.bar(bottom_10_2010['Country Name'], bottom_10_2010['2010'], width=0.4, label='2010', align='center')
plt.bar(bottom_10_2001['Country Name'], bottom_10_2001['2001'], width=0.4, label='2001', align='edge')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Population')
plt.title('Bottom 10 Countries by Total Population in 2001 and 2010')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extraction of top ten countries with highest male population
top_10_male_2022 = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=False).head(10)
print(top_10_male_2022)
# Out:
#                    Country Name          2022
# 259                       World  7.950947e+09
# 103            IDA & IBRD total  6.754030e+09
# 140         Low & middle income  6.678280e+09
# 156               Middle income  5.974552e+09
# 102                   IBRD only  4.913887e+09
# 62   Early-demographic dividend  3.447399e+09
# 139         Lower middle income  3.190184e+09
# 249         Upper middle income  2.784368e+09
# 63          East Asia & Pacific  2.375162e+09
# 142   Late-demographic dividend  2.325543e+09

# %%
# Extraction of top ten countries with highest female population
top_10_female_2022 = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=False).head(10)
print(top_10_female_2022)
# Out:
#                    Country Name          2022
# 259                       World  7.950947e+09
# 103            IDA & IBRD total  6.754030e+09
# 140         Low & middle income  6.678280e+09
# 156               Middle income  5.974552e+09
# 102                   IBRD only  4.913887e+09
# 62   Early-demographic dividend  3.447399e+09
# 139         Lower middle income  3.190184e+09
# 249         Upper middle income  2.784368e+09
# 63          East Asia & Pacific  2.375162e+09
# 142   Late-demographic dividend  2.325543e+09

# %%
# Top ten countries with highest male and female population in 2022

# Top ten countries with highest male population in 2022
plt.figure(figsize=(12, 6))
plt.bar(top_10_male_2022['Country Name'], top_10_male_2022['2022'], color='grey')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Male Population')
plt.title('Top 10 Countries with Highest Male Population in 2022')
plt.tight_layout()
plt.show()

# %%
# Top ten countries with highest male and female population in 2022

# Top ten countries with highest female population in 2022
plt.figure(figsize=(12, 6))
plt.bar(top_10_female_2022['Country Name'], top_10_female_2022['2022'], color='pink')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Female Population')
plt.title('Top 10 Countries with Highest Female Population in 2022')
plt.tight_layout()
plt.show()

# %%
# Extraction of top ten countries with lowest male population
bottom_10_male_2022 = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=True).head(10)
print(bottom_10_male_2022)
# Out:
#                  Country Name     2022
# 245                    Tuvalu  11312.0
# 179                     Nauru  12668.0
# 188                     Palau  18055.0
# 255    British Virgin Islands  31305.0
# 147  St. Martin (French part)  31791.0
# 84                  Gibraltar  32649.0
# 212                San Marino  33660.0
# 149                    Monaco  36469.0
# 137             Liechtenstein  39327.0
# 155          Marshall Islands  41569.0

# %%
# Extraction of top ten countries with lowest female population
bottom_10_female_2022 = df_cleaned[['Country Name', '2022']].sort_values(by='2022', ascending=True).head(10)
print(bottom_10_female_2022)
# Out:
#                  Country Name     2022
# 245                    Tuvalu  11312.0
# 179                     Nauru  12668.0
# 188                     Palau  18055.0
# 255    British Virgin Islands  31305.0
# 147  St. Martin (French part)  31791.0
# 84                  Gibraltar  32649.0
# 212                San Marino  33660.0
# 149                    Monaco  36469.0
# 137             Liechtenstein  39327.0
# 155          Marshall Islands  41569.0

# %%
# Top ten countries with lowest male and female population in 2022
# Top ten countries with lowest male population in 2022
plt.figure(figsize=(12, 6))
plt.bar(bottom_10_male_2022['Country Name'], bottom_10_male_2022['2022'], color='grey', width=0.4, label='Male')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Male Population', size=10)
plt.ylabel('Country', size=10)
plt.title('Top 10 Countries with Lowest Male Population in 2022')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with Lowest Male Population in 2022')

# %%
# Top ten countries with lowest female population in 2022
plt.figure(figsize=(12, 6))
plt.bar(bottom_10_female_2022['Country Name'], bottom_10_female_2022['2022'], color='pink', width=0.4, label='Female')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Female Population', size=10)
plt.ylabel('Country', size=10)
plt.title('Top 10 Countries with Lowest Female Population in 2022')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with Lowest Female Population in 2022')

# %%
# Filter only "Population, total" for 2022
total_df = df[df['Indicator Name'] == 'Population, total'][['Country Name', '2022']].rename(columns={'2022': 'Total_Population'})

# Get bottom 10 countries by population in 2022 (excluding NaN)
bottom10_total = total_df.dropna().sort_values(by='Total_Population', ascending=True).head(10)

print(bottom10_total)
# Out:
#                  Country Name  Total_Population
# 245                    Tuvalu           11312.0
# 179                     Nauru           12668.0
# 188                     Palau           18055.0
# 255    British Virgin Islands           31305.0
# 147  St. Martin (French part)           31791.0
# 84                  Gibraltar           32649.0
# 212                San Marino           33660.0
# 149                    Monaco           36469.0
# 137             Liechtenstein           39327.0
# 155          Marshall Islands           41569.0

# %%
# Filter only "Population, total" for 2022
total_df = df[df['Indicator Name'] == 'Population, total'][['Country Name', '2022']].rename(columns={'2022': 'Total_Population'})

# Get bottom 10 countries by population in 2022 (excluding NaN)
bottom10_total = total_df.dropna().sort_values(by='Total_Population', ascending=True).head(10)

# Plot bar chart
plt.figure(figsize=(10,6))
plt.bar(bottom10_total['Country Name'], bottom10_total['Total_Population'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.title("Bottom 10 Countries by Total Population (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.tight_layout()
plt.show()
